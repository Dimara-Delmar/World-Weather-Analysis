# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 782

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_describe = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_describe})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | wewak
# Processing Record 4 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 1 | jibuti
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | atar
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | bartoszyce
# Processing Record 13 of Set 1 | namibe
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | inhambane
# Processing Record 16 of Set 1 | riyadh
# Processing Record 17 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 1 | kirakira
# Processing Record 19 of Set 1 | bull savanna
# Processing Record 20 of Set 1 | salina
# Processing Record 21 of Set 1 | malartic
# Processing Record 22 of Set 1 | avera
# Processing Record 23 of Set 1 | niono
# Processing Record 24 of Set 1 | sestri levante
# Processing Record 25 of Set 1 | fortuna
# Processing Record 26 of Set 1 | ixtapa
# Processing Record 27 of Set 1 | geraldton
# Processing Record 28 of Set 1 | chapais
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | sisimiut
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | college
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | chiredzi
# Processing Record 41 of Set 1 | thinadhoo
# Processing Record 42 of Set 1 | asau
# Processing Record 43 of Set 1 | cesvaine
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | tocopilla
# Processing Record 46 of Set 1 | yumen
# Processing Record 47 of Set 1 | bambous virieux
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | puerto escondido
# Processing Record 2 of Set 2 | hervey bay
# Processing Record 3 of Set 2 | byron bay
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | lebu
# Processing Record 6 of Set 2 | laguna
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | touros
# Processing Record 9 of Set 2 | srednekolymsk
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | tasiilaq
# Processing Record 12 of Set 2 | belmonte
# Processing Record 13 of Set 2 | flinders
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | leningradskiy
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | qui nhon
# Processing Record 19 of Set 2 | butaritari
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | mount gambier
# Processing Record 23 of Set 2 | vaitape
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | san patricio
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | jalu
# Processing Record 30 of Set 2 | qurbus
# Processing Record 31 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 2 | klaksvik
# Processing Record 33 of Set 2 | carutapera
# Processing Record 34 of Set 2 | tautira
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | dukat
# Processing Record 37 of Set 2 | beruwala
# Processing Record 38 of Set 2 | marienburg
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | okhotsk
# Processing Record 41 of Set 2 | kaeo
# Processing Record 42 of Set 2 | ketchikan
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | culipapa
# City not found. Skipping...
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | naantali
# Processing Record 48 of Set 2 | whitehorse
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | aras
# Processing Record 1 of Set 3 | kropotkin
# City not found. Skipping...
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | kavaratti
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | vilhena
# Processing Record 7 of Set 3 | rafai
# Processing Record 8 of Set 3 | boke
# Processing Record 9 of Set 3 | bubaque
# Processing Record 10 of Set 3 | adelanto
# Processing Record 11 of Set 3 | matai
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | bella union
# Processing Record 15 of Set 3 | saint-georges
# Processing Record 16 of Set 3 | baloda bazar
# Processing Record 17 of Set 3 | victorville
# Processing Record 18 of Set 3 | dubovskoye
# Processing Record 19 of Set 3 | sabha
# Processing Record 20 of Set 3 | kapaa
# Processing Record 21 of Set 3 | puerto baquerizo moreno
# Processing Record 22 of Set 3 | san pedro de ycuamandiyu
# Processing Record 23 of Set 3 | goundam
# Processing Record 24 of Set 3 | bluff
# Processing Record 25 of Set 3 | aksu
# Processing Record 26 of Set 3 | brae
# Processing Record 27 of Set 3 | dubna
# Processing Record 28 of Set 3 | pontianak
# Processing Record 29 of Set 3 | sao filipe
# Processing Record 30 of Set 3 | port hardy
# Processing Record 31 of Set 3 | castro
# Processing Record 32 of Set 3 | mosquera
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | manokwari
# Processing Record 35 of Set 3 | port augusta
# Processing Record 36 of Set 3 | katsuura
# Processing Record 37 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 3 | chicama
# Processing Record 39 of Set 3 | mana
# Processing Record 40 of Set 3 | circleville
# Processing Record 41 of Set 3 | matay
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | saint pete beach
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | skibbereen
# Processing Record 47 of Set 3 | beringovskiy
# Processing Record 48 of Set 3 | mompos
# Processing Record 49 of Set 3 | yakeshi
# Processing Record 50 of Set 3 | ginir
# Processing Record 1 of Set 4 | ahome
# Processing Record 2 of Set 4 | henties bay
# Processing Record 3 of Set 4 | walvis bay
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | oriximina
# Processing Record 6 of Set 4 | ahuimanu
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | sobolevo
# Processing Record 10 of Set 4 | kjopsvik
# Processing Record 11 of Set 4 | carballo
# Processing Record 12 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 4 | chara
# Processing Record 14 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 4 | batemans bay
# Processing Record 16 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 4 | vao
# Processing Record 18 of Set 4 | ilembula
# Processing Record 19 of Set 4 | cascais
# Processing Record 20 of Set 4 | pangnirtung
# Processing Record 21 of Set 4 | tazovskiy
# Processing Record 22 of Set 4 | morehead
# Processing Record 23 of Set 4 | east millcreek
# Processing Record 24 of Set 4 | lasa
# Processing Record 25 of Set 4 | sinnar
# Processing Record 26 of Set 4 | araouane
# Processing Record 27 of Set 4 | ambunti
# Processing Record 28 of Set 4 | severo-kurilsk
# Processing Record 29 of Set 4 | valparaiso
# Processing Record 30 of Set 4 | luderitz
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | gamba
# Processing Record 34 of Set 4 | powassan
# Processing Record 35 of Set 4 | namatanai
# Processing Record 36 of Set 4 | sohbatpur
# Processing Record 37 of Set 4 | rawson
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | paciran
# Processing Record 41 of Set 4 | hofn
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | priladozhskiy
# Processing Record 44 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 45 of Set 4 | high rock
# Processing Record 46 of Set 4 | san jose
# Processing Record 47 of Set 4 | mozarlandia
# Processing Record 48 of Set 4 | lodja
# Processing Record 49 of Set 4 | ponta delgada
# Processing Record 50 of Set 4 | abha
# Processing Record 1 of Set 5 | quirinopolis
# Processing Record 2 of Set 5 | presidencia roque saenz pena
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | zanjan
# Processing Record 8 of Set 5 | puerto del rosario
# Processing Record 9 of Set 5 | saint-joseph
# Processing Record 10 of Set 5 | ilhabela
# Processing Record 11 of Set 5 | sola
# Processing Record 12 of Set 5 | nome
# Processing Record 13 of Set 5 | tevriz
# Processing Record 14 of Set 5 | saint george
# Processing Record 15 of Set 5 | antofagasta
# Processing Record 16 of Set 5 | araioses
# Processing Record 17 of Set 5 | nainpur
# Processing Record 18 of Set 5 | santa rosalia
# Processing Record 19 of Set 5 | meadow lake
# Processing Record 20 of Set 5 | yaan
# Processing Record 21 of Set 5 | kaoma
# Processing Record 22 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | markova
# Processing Record 26 of Set 5 | myanaung
# Processing Record 27 of Set 5 | kloulklubed
# Processing Record 28 of Set 5 | russell
# Processing Record 29 of Set 5 | ahipara
# Processing Record 30 of Set 5 | severobaykalsk
# Processing Record 31 of Set 5 | asmar
# Processing Record 32 of Set 5 | berlevag
# Processing Record 33 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 5 | graciano sanchez
# Processing Record 35 of Set 5 | pahrump
# Processing Record 36 of Set 5 | kabelvag
# Processing Record 37 of Set 5 | bolu
# Processing Record 38 of Set 5 | beloha
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | cidreira
# Processing Record 41 of Set 5 | kutum
# Processing Record 42 of Set 5 | iqaluit
# Processing Record 43 of Set 5 | barela
# Processing Record 44 of Set 5 | saint-philippe
# Processing Record 45 of Set 5 | mrakovo
# Processing Record 46 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 5 | honiara
# Processing Record 48 of Set 5 | arraial do cabo
# Processing Record 49 of Set 5 | faanui
# Processing Record 50 of Set 5 | rio gallegos
# Processing Record 1 of Set 6 | basco
# Processing Record 2 of Set 6 | arona
# Processing Record 3 of Set 6 | marzuq
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | canon city
# Processing Record 6 of Set 6 | afantou
# Processing Record 7 of Set 6 | hirado
# Processing Record 8 of Set 6 | tura
# Processing Record 9 of Set 6 | kruisfontein
# Processing Record 10 of Set 6 | fulton
# Processing Record 11 of Set 6 | borovskoy
# Processing Record 12 of Set 6 | boffa
# Processing Record 13 of Set 6 | kendari
# Processing Record 14 of Set 6 | hovd
# Processing Record 15 of Set 6 | cabo san lucas
# Processing Record 16 of Set 6 | la ronge
# Processing Record 17 of Set 6 | mata
# Processing Record 18 of Set 6 | karasuk
# Processing Record 19 of Set 6 | uige
# Processing Record 20 of Set 6 | paamiut
# Processing Record 21 of Set 6 | prado
# Processing Record 22 of Set 6 | keti bandar
# Processing Record 23 of Set 6 | anchorage
# Processing Record 24 of Set 6 | carnarvon
# Processing Record 25 of Set 6 | aswan
# Processing Record 26 of Set 6 | erzin
# Processing Record 27 of Set 6 | kaitangata
# Processing Record 28 of Set 6 | muisne
# Processing Record 29 of Set 6 | provideniya
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | mehamn
# Processing Record 32 of Set 6 | kuzedeyevo
# Processing Record 33 of Set 6 | ishigaki
# Processing Record 34 of Set 6 | qaanaaq
# Processing Record 35 of Set 6 | svetlaya
# Processing Record 36 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 37 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 38 of Set 6 | gizo
# Processing Record 39 of Set 6 | corning
# Processing Record 40 of Set 6 | grand gaube
# Processing Record 41 of Set 6 | luanda
# Processing Record 42 of Set 6 | santa maria del oro
# Processing Record 43 of Set 6 | fairbanks
# Processing Record 44 of Set 6 | havoysund
# Processing Record 45 of Set 6 | derzhavinsk
# Processing Record 46 of Set 6 | las vegas
# Processing Record 47 of Set 6 | candelaria
# Processing Record 48 of Set 6 | beinamar
# Processing Record 49 of Set 6 | port lincoln
# Processing Record 50 of Set 6 | dakoro
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | portland
# Processing Record 3 of Set 7 | phuket
# Processing Record 4 of Set 7 | marawi
# Processing Record 5 of Set 7 | san vicente
# Processing Record 6 of Set 7 | norman wells
# Processing Record 7 of Set 7 | guerrero negro
# Processing Record 8 of Set 7 | port-gentil
# Processing Record 9 of Set 7 | muromtsevo
# Processing Record 10 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 11 of Set 7 | vesyegonsk
# Processing Record 12 of Set 7 | lokosovo
# Processing Record 13 of Set 7 | jeremie
# Processing Record 14 of Set 7 | ayan
# Processing Record 15 of Set 7 | mayo
# Processing Record 16 of Set 7 | salym
# Processing Record 17 of Set 7 | nyrob
# Processing Record 18 of Set 7 | seoul
# Processing Record 19 of Set 7 | gimbi
# Processing Record 20 of Set 7 | alice springs
# Processing Record 21 of Set 7 | alekseyevsk
# Processing Record 22 of Set 7 | north platte
# Processing Record 23 of Set 7 | tuatapere
# Processing Record 24 of Set 7 | lahaina
# Processing Record 25 of Set 7 | usinsk
# Processing Record 26 of Set 7 | ostrovnoy
# Processing Record 27 of Set 7 | majene
# Processing Record 28 of Set 7 | chuy
# Processing Record 29 of Set 7 | miram shah
# Processing Record 30 of Set 7 | cortes
# Processing Record 31 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 7 | lagoa
# Processing Record 33 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 7 | broken hill
# Processing Record 35 of Set 7 | gondanglegi
# Processing Record 36 of Set 7 | santa cruz
# Processing Record 37 of Set 7 | tumut
# Processing Record 38 of Set 7 | kahului
# Processing Record 39 of Set 7 | ponta do sol
# Processing Record 40 of Set 7 | kodiak
# Processing Record 41 of Set 7 | kushmurun
# Processing Record 42 of Set 7 | lavrentiya
# Processing Record 43 of Set 7 | shadrinsk
# Processing Record 44 of Set 7 | mannarakkat
# Processing Record 45 of Set 7 | canberra
# Processing Record 46 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 7 | rabaul
# Processing Record 48 of Set 7 | san juan
# Processing Record 49 of Set 7 | monywa
# Processing Record 50 of Set 7 | porto de moz
# Processing Record 1 of Set 8 | bac lieu
# Processing Record 2 of Set 8 | dwarka
# Processing Record 3 of Set 8 | gravdal
# Processing Record 4 of Set 8 | teofilo otoni
# Processing Record 5 of Set 8 | zeya
# Processing Record 6 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 8 | benton harbor
# Processing Record 8 of Set 8 | yei
# Processing Record 9 of Set 8 | nyurba
# Processing Record 10 of Set 8 | padang
# Processing Record 11 of Set 8 | maldonado
# Processing Record 12 of Set 8 | jishou
# Processing Record 13 of Set 8 | srebrenica
# Processing Record 14 of Set 8 | tiksi
# Processing Record 15 of Set 8 | bucerias
# Processing Record 16 of Set 8 | wilmington
# Processing Record 17 of Set 8 | esil
# Processing Record 18 of Set 8 | tshikapa
# Processing Record 19 of Set 8 | mocuba
# Processing Record 20 of Set 8 | eagle pass
# Processing Record 21 of Set 8 | camocim
# Processing Record 22 of Set 8 | zuwarah
# Processing Record 23 of Set 8 | noumea
# Processing Record 24 of Set 8 | baindur
# Processing Record 25 of Set 8 | tommot
# Processing Record 26 of Set 8 | biu
# Processing Record 27 of Set 8 | kashmor
# Processing Record 28 of Set 8 | sitka
# Processing Record 29 of Set 8 | tulun
# Processing Record 30 of Set 8 | cap-haitien
# Processing Record 31 of Set 8 | pacific grove
# Processing Record 32 of Set 8 | gabu
# Processing Record 33 of Set 8 | knin
# Processing Record 34 of Set 8 | raudeberg
# Processing Record 35 of Set 8 | guatire
# Processing Record 36 of Set 8 | novobiryusinskiy
# Processing Record 37 of Set 8 | chumikan
# Processing Record 38 of Set 8 | saint-jean-de-maurienne
# Processing Record 39 of Set 8 | mackay
# Processing Record 40 of Set 8 | shaunavon
# Processing Record 41 of Set 8 | hof
# Processing Record 42 of Set 8 | strezhevoy
# Processing Record 43 of Set 8 | saskylakh
# Processing Record 44 of Set 8 | hirara
# Processing Record 45 of Set 8 | niquelandia
# Processing Record 46 of Set 8 | ambilobe
# Processing Record 47 of Set 8 | obanazawa
# Processing Record 48 of Set 8 | eureka
# Processing Record 49 of Set 8 | milkovo
# Processing Record 50 of Set 8 | rizhao
# Processing Record 1 of Set 9 | muros
# Processing Record 2 of Set 9 | cayenne
# Processing Record 3 of Set 9 | hobyo
# Processing Record 4 of Set 9 | karratha
# Processing Record 5 of Set 9 | pochutla
# Processing Record 6 of Set 9 | atambua
# Processing Record 7 of Set 9 | olinda
# Processing Record 8 of Set 9 | ilulissat
# Processing Record 9 of Set 9 | bathsheba
# Processing Record 10 of Set 9 | paita
# Processing Record 11 of Set 9 | kristiansund
# Processing Record 12 of Set 9 | wukari
# Processing Record 13 of Set 9 | kasangulu
# Processing Record 14 of Set 9 | susangerd
# Processing Record 15 of Set 9 | phak hai
# Processing Record 16 of Set 9 | sawakin
# Processing Record 17 of Set 9 | nieuw amsterdam
# Processing Record 18 of Set 9 | valenca
# Processing Record 19 of Set 9 | udachnyy
# Processing Record 20 of Set 9 | vostok
# Processing Record 21 of Set 9 | bastia
# Processing Record 22 of Set 9 | kirkuk
# Processing Record 23 of Set 9 | andenes
# Processing Record 24 of Set 9 | bairiki
# Processing Record 25 of Set 9 | ust-ilimsk
# Processing Record 26 of Set 9 | bay roberts
# Processing Record 27 of Set 9 | kargasok
# Processing Record 28 of Set 9 | sao felix do xingu
# Processing Record 29 of Set 9 | dubai
# Processing Record 30 of Set 9 | biak
# Processing Record 31 of Set 9 | lydenburg
# Processing Record 32 of Set 9 | moncao
# Processing Record 33 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 9 | swan river
# Processing Record 35 of Set 9 | dire
# Processing Record 36 of Set 9 | isangel
# Processing Record 37 of Set 9 | maumere
# Processing Record 38 of Set 9 | narsaq
# Processing Record 39 of Set 9 | posevnaya
# Processing Record 40 of Set 9 | kampot
# Processing Record 41 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 42 of Set 9 | nesna
# Processing Record 43 of Set 9 | zaysan
# Processing Record 44 of Set 9 | san quintin
# Processing Record 45 of Set 9 | kavieng
# Processing Record 46 of Set 9 | khangarh
# Processing Record 47 of Set 9 | aguimes
# Processing Record 48 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 49 of Set 9 | quesnel
# Processing Record 50 of Set 9 | osypenko
# Processing Record 1 of Set 10 | rodrigues alves
# Processing Record 2 of Set 10 | matara
# Processing Record 3 of Set 10 | kamenka
# Processing Record 4 of Set 10 | sur
# Processing Record 5 of Set 10 | burica
# City not found. Skipping...
# Processing Record 6 of Set 10 | sainte-rose
# Processing Record 7 of Set 10 | santa maria
# Processing Record 8 of Set 10 | excelsior springs
# Processing Record 9 of Set 10 | jinchang
# Processing Record 10 of Set 10 | lingao
# Processing Record 11 of Set 10 | jumla
# Processing Record 12 of Set 10 | charters towers
# Processing Record 13 of Set 10 | pavilosta
# Processing Record 14 of Set 10 | tabou
# Processing Record 15 of Set 10 | nouadhibou
# Processing Record 16 of Set 10 | brokopondo
# Processing Record 17 of Set 10 | san cristobal
# Processing Record 18 of Set 10 | dingli
# Processing Record 19 of Set 10 | neyshabur
# Processing Record 20 of Set 10 | fare
# Processing Record 21 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 22 of Set 10 | white oak
# Processing Record 23 of Set 10 | mount isa
# Processing Record 24 of Set 10 | kiboga
# Processing Record 25 of Set 10 | nueva loja
# Processing Record 26 of Set 10 | bemidji
# Processing Record 27 of Set 10 | vyartsilya
# Processing Record 28 of Set 10 | melilla
# Processing Record 29 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 10 | menongue
# Processing Record 31 of Set 10 | douglas
# Processing Record 32 of Set 10 | lenger
# Processing Record 33 of Set 10 | kushima
# Processing Record 34 of Set 10 | port hedland
# Processing Record 35 of Set 10 | leshukonskoye
# Processing Record 36 of Set 10 | la palma
# Processing Record 37 of Set 10 | shimoda
# Processing Record 38 of Set 10 | maneromango
# Processing Record 39 of Set 10 | mandalgovi
# Processing Record 40 of Set 10 | dieppe
# Processing Record 41 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 10 | caravelas
# Processing Record 43 of Set 10 | kumbo
# Processing Record 44 of Set 10 | pamyat parizhskoy kommuny
# Processing Record 45 of Set 10 | olafsvik
# Processing Record 46 of Set 10 | labuhan
# Processing Record 47 of Set 10 | ampanihy
# Processing Record 48 of Set 10 | saint anthony
# Processing Record 49 of Set 10 | dakar
# Processing Record 50 of Set 10 | souillac
# Processing Record 1 of Set 11 | mitu
# Processing Record 2 of Set 11 | huarmey
# Processing Record 3 of Set 11 | alofi
# Processing Record 4 of Set 11 | kabompo
# Processing Record 5 of Set 11 | cabinda
# Processing Record 6 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 11 | bjornevatn
# Processing Record 8 of Set 11 | pudozh
# Processing Record 9 of Set 11 | orlik
# Processing Record 10 of Set 11 | sao joao da barra
# Processing Record 11 of Set 11 | hearst
# Processing Record 12 of Set 11 | hasaki
# Processing Record 13 of Set 11 | srandakan
# Processing Record 14 of Set 11 | velsk
# Processing Record 15 of Set 11 | garissa
# Processing Record 16 of Set 11 | huntsville
# Processing Record 17 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 11 | banda aceh
# Processing Record 19 of Set 11 | esperance
# Processing Record 20 of Set 11 | athboy
# Processing Record 21 of Set 11 | santarem
# Processing Record 22 of Set 11 | mtambile
# Processing Record 23 of Set 11 | iquique
# Processing Record 24 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 11 | pascagoula
# Processing Record 26 of Set 11 | pierreville
# Processing Record 27 of Set 11 | erenhot
# Processing Record 28 of Set 11 | nanyang
# Processing Record 29 of Set 11 | ust-nera
# Processing Record 30 of Set 11 | mayumba
# Processing Record 31 of Set 11 | qasigiannguit
# Processing Record 32 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 11 | big bend
# Processing Record 34 of Set 11 | cheyenne
# Processing Record 35 of Set 11 | sioux lookout
# Processing Record 36 of Set 11 | lazaro cardenas
# Processing Record 37 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 11 | banepa
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | buala
# Processing Record 41 of Set 11 | vila franca do campo
# Processing Record 42 of Set 11 | port macquarie
# Processing Record 43 of Set 11 | palana
# Processing Record 44 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 45 of Set 11 | the valley
# Processing Record 46 of Set 11 | eslamshahr
# Processing Record 47 of Set 11 | waterloo
# Processing Record 48 of Set 11 | nagato
# Processing Record 49 of Set 11 | nago
# Processing Record 50 of Set 11 | sorland
# Processing Record 1 of Set 12 | oranjemund
# Processing Record 2 of Set 12 | novikovo
# Processing Record 3 of Set 12 | alta floresta
# Processing Record 4 of Set 12 | arica
# Processing Record 5 of Set 12 | bilma
# Processing Record 6 of Set 12 | birao
# Processing Record 7 of Set 12 | vanavara
# Processing Record 8 of Set 12 | acapulco
# Processing Record 9 of Set 12 | margate
# Processing Record 10 of Set 12 | miracema do tocantins
# Processing Record 11 of Set 12 | asyut
# Processing Record 12 of Set 12 | ewa beach
# Processing Record 13 of Set 12 | baoshan
# Processing Record 14 of Set 12 | flin flon
# Processing Record 15 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | ugoofaaru
# Processing Record 17 of Set 12 | mezen
# Processing Record 18 of Set 12 | kottagudem
# Processing Record 19 of Set 12 | alyangula
# Processing Record 20 of Set 12 | krasnoborsk
# Processing Record 21 of Set 12 | lucapa
# Processing Record 22 of Set 12 | sal rei
# Processing Record 23 of Set 12 | boiro
# Processing Record 24 of Set 12 | tessalit
# Processing Record 25 of Set 12 | zhanaozen
# Processing Record 26 of Set 12 | carson city
# Processing Record 27 of Set 12 | iquitos
# Processing Record 28 of Set 12 | unai
# Processing Record 29 of Set 12 | guiglo
# Processing Record 30 of Set 12 | samarinda
# Processing Record 31 of Set 12 | lorengau
# Processing Record 32 of Set 12 | vrangel
# Processing Record 33 of Set 12 | coquimbo
# Processing Record 34 of Set 12 | kununurra
# Processing Record 35 of Set 12 | salto
# Processing Record 36 of Set 12 | pacifica
# Processing Record 37 of Set 12 | tomatlan
# Processing Record 38 of Set 12 | gawler
# Processing Record 39 of Set 12 | kysyl-syr
# Processing Record 40 of Set 12 | calabozo
# Processing Record 41 of Set 12 | miami
# Processing Record 42 of Set 12 | hualmay
# Processing Record 43 of Set 12 | bud
# Processing Record 44 of Set 12 | abrau-dyurso
# Processing Record 45 of Set 12 | vila velha
# Processing Record 46 of Set 12 | fukue
# Processing Record 47 of Set 12 | cantagalo
# Processing Record 48 of Set 12 | ozernovskiy
# Processing Record 49 of Set 12 | umm lajj
# Processing Record 50 of Set 12 | moron
# Processing Record 1 of Set 13 | kudahuvadhoo
# Processing Record 2 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 3 of Set 13 | lufkin
# Processing Record 4 of Set 13 | podgornoye
# Processing Record 5 of Set 13 | nara
# Processing Record 6 of Set 13 | sergeyevka
# Processing Record 7 of Set 13 | masaka
# Processing Record 8 of Set 13 | black river
# Processing Record 9 of Set 13 | camacha
# Processing Record 10 of Set 13 | raga
# Processing Record 11 of Set 13 | ko samui
# Processing Record 12 of Set 13 | maues
# Processing Record 13 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 13 | khor
# Processing Record 16 of Set 13 | abnub
# Processing Record 17 of Set 13 | taoudenni
# Processing Record 18 of Set 13 | cosala
# Processing Record 19 of Set 13 | bloemfontein
# Processing Record 20 of Set 13 | marquette
# Processing Record 21 of Set 13 | rio grande
# Processing Record 22 of Set 13 | jati
# Processing Record 23 of Set 13 | wesselsbron
# Processing Record 24 of Set 13 | el paraiso
# Processing Record 25 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 13 | trinidad
# Processing Record 27 of Set 13 | podor
# Processing Record 28 of Set 13 | ushtobe
# Processing Record 29 of Set 13 | suriapet
# Processing Record 30 of Set 13 | ukiah
# Processing Record 31 of Set 13 | lipari
# Processing Record 32 of Set 13 | aksarka
# Processing Record 33 of Set 13 | pozo colorado
# Processing Record 34 of Set 13 | nantucket
# Processing Record 35 of Set 13 | vanimo
# Processing Record 36 of Set 13 | gat
# Processing Record 37 of Set 13 | barbastro
# Processing Record 38 of Set 13 | husavik
# Processing Record 39 of Set 13 | chivay
# Processing Record 40 of Set 13 | saquarema
# Processing Record 41 of Set 13 | axim
# Processing Record 42 of Set 13 | cockburn town
# Processing Record 43 of Set 13 | buchanan
# Processing Record 44 of Set 13 | parry sound
# Processing Record 45 of Set 13 | kondinskoye
# Processing Record 46 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 13 | kumano
# Processing Record 48 of Set 13 | nizhniy kuranakh
# Processing Record 49 of Set 13 | werda
# Processing Record 50 of Set 13 | koslan
# Processing Record 1 of Set 14 | tatarsk
# Processing Record 2 of Set 14 | mattru
# Processing Record 3 of Set 14 | samarai
# Processing Record 4 of Set 14 | farah
# Processing Record 5 of Set 14 | hope
# Processing Record 6 of Set 14 | svetlyy
# Processing Record 7 of Set 14 | old road
# City not found. Skipping...
# Processing Record 8 of Set 14 | svirstroy
# Processing Record 9 of Set 14 | seymchan
# Processing Record 10 of Set 14 | kualakapuas
# Processing Record 11 of Set 14 | ziyamet
# City not found. Skipping...
# Processing Record 12 of Set 14 | cumpas
# Processing Record 13 of Set 14 | ornskoldsvik
# Processing Record 14 of Set 14 | yatou
# Processing Record 15 of Set 14 | dalvik
# Processing Record 16 of Set 14 | matagami
# Processing Record 17 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 14 | kaspiyskiy
# Processing Record 19 of Set 14 | murray bridge
# Processing Record 20 of Set 14 | solnechnyy
# Processing Record 21 of Set 14 | ancud
# Processing Record 22 of Set 14 | moranbah
# Processing Record 23 of Set 14 | meulaboh
# Processing Record 24 of Set 14 | kajaani
# Processing Record 25 of Set 14 | felipe carrillo puerto
# Processing Record 26 of Set 14 | diego de almagro
# Processing Record 27 of Set 14 | ostersund
# Processing Record 28 of Set 14 | izhmorskiy
# Processing Record 29 of Set 14 | rundu
# Processing Record 30 of Set 14 | redlands
# Processing Record 31 of Set 14 | saint paul
# Processing Record 32 of Set 14 | toamasina
# Processing Record 33 of Set 14 | itarema
# Processing Record 34 of Set 14 | lengshuijiang
# Processing Record 35 of Set 14 | launceston
# Processing Record 36 of Set 14 | navrongo
# Processing Record 37 of Set 14 | tari
# Processing Record 38 of Set 14 | ipojuca
# Processing Record 39 of Set 14 | nishihara
# Processing Record 40 of Set 14 | maceio
# Processing Record 41 of Set 14 | oktyabrskoye
# Processing Record 42 of Set 14 | muzhi
# Processing Record 43 of Set 14 | cururupu
# Processing Record 44 of Set 14 | hadrut
# Processing Record 45 of Set 14 | langham
# Processing Record 46 of Set 14 | baiao
# Processing Record 47 of Set 14 | surgut
# Processing Record 48 of Set 14 | saint-augustin
# Processing Record 49 of Set 14 | novyy urengoy
# Processing Record 50 of Set 14 | coos bay
# Processing Record 1 of Set 15 | keetmanshoop
# Processing Record 2 of Set 15 | jiamusi
# Processing Record 3 of Set 15 | kushiro
# Processing Record 4 of Set 15 | itaituba
# Processing Record 5 of Set 15 | comodoro rivadavia
# Processing Record 6 of Set 15 | yelizovo
# Processing Record 7 of Set 15 | saint-andre-les-vergers
# Processing Record 8 of Set 15 | baherden
# Processing Record 9 of Set 15 | bagdarin
# Processing Record 10 of Set 15 | cayhagan
# Processing Record 11 of Set 15 | olinala
# Processing Record 12 of Set 15 | zhezkazgan
# Processing Record 13 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 14 of Set 15 | inuvik
# Processing Record 15 of Set 15 | taseyevo
# Processing Record 16 of Set 15 | road town
# Processing Record 17 of Set 15 | north bend
# Processing Record 18 of Set 15 | mednogorsk
# Processing Record 19 of Set 15 | balykshi
# Processing Record 20 of Set 15 | troitskoye
# Processing Record 21 of Set 15 | jiaojiang
# Processing Record 22 of Set 15 | lima
# Processing Record 23 of Set 15 | waipawa
# Processing Record 24 of Set 15 | korgen
# Processing Record 25 of Set 15 | boca do acre
# Processing Record 26 of Set 15 | kenai
# Processing Record 27 of Set 15 | poli
# Processing Record 28 of Set 15 | faya
# Processing Record 29 of Set 15 | dalbandin
# Processing Record 30 of Set 15 | duz
# City not found. Skipping...
# Processing Record 31 of Set 15 | moctezuma
# Processing Record 32 of Set 15 | cajititlan
# Processing Record 33 of Set 15 | abu dhabi
# Processing Record 34 of Set 15 | moindou
# Processing Record 35 of Set 15 | komsomolskiy
# Processing Record 36 of Set 15 | tawau
# Processing Record 37 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 15 | preobrazheniye
# Processing Record 39 of Set 15 | la trinidad
# Processing Record 40 of Set 15 | carauari
# Processing Record 41 of Set 15 | rocha
# Processing Record 42 of Set 15 | richards bay
# Processing Record 43 of Set 15 | arlit
# Processing Record 44 of Set 15 | praia
# Processing Record 45 of Set 15 | ormara
# Processing Record 46 of Set 15 | denpasar
# Processing Record 47 of Set 15 | camapua
# Processing Record 48 of Set 15 | maragogi
# Processing Record 49 of Set 15 | sibolga
# Processing Record 50 of Set 15 | pecos
# Processing Record 1 of Set 16 | christchurch
# Processing Record 2 of Set 16 | deputatskiy
# Processing Record 3 of Set 16 | finschhafen
# Processing Record 4 of Set 16 | amapa
# Processing Record 5 of Set 16 | kashan
# Processing Record 6 of Set 16 | neiafu
# Processing Record 7 of Set 16 | kaduqli
# Processing Record 8 of Set 16 | pundaguitan
# Processing Record 9 of Set 16 | la orilla
# Processing Record 10 of Set 16 | tambun
# Processing Record 11 of Set 16 | pasewalk
# Processing Record 12 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 16 | swellendam
# Processing Record 14 of Set 16 | erdenet
# Processing Record 15 of Set 16 | cedar city
# Processing Record 16 of Set 16 | boa vista
# Processing Record 17 of Set 16 | karoi
# Processing Record 18 of Set 16 | panzhihua
# Processing Record 19 of Set 16 | ballstad
# City not found. Skipping...
# Processing Record 20 of Set 16 | itupeva
# Processing Record 21 of Set 16 | batsfjord
# Processing Record 22 of Set 16 | egvekinot
# Processing Record 23 of Set 16 | sulphur
# Processing Record 24 of Set 16 | stephenville
# Processing Record 25 of Set 16 | alcala de henares
# Processing Record 26 of Set 16 | yar-sale
# Processing Record 27 of Set 16 | tyazhinskiy
# Processing Record 28 of Set 16 | port blair
# Processing Record 29 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 16 | havre-saint-pierre
# Processing Record 31 of Set 16 | saint-francois
# Processing Record 32 of Set 16 | san carlos de bariloche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 729

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Rikitea -23.1203 -134.9692     73.27        89         100       24.02
# 1  East London -33.0153   27.9116     64.98        79         100        2.19
# 2        Wewak  -3.5534  143.6268     86.11        66         100        4.63
# 3       Jibuti  11.5000   42.5000     69.75        76           4       10.13
# 4  Port Alfred -33.5906   26.8910     62.19        95          98        6.31
# 5     Khatanga  71.9667  102.5000    -27.71       100          94        5.10
# 6     Hermanus -34.4187   19.2345     52.81        72          97        4.59
# 7   Codrington -38.2667  141.9667     58.21        65          89        9.71
# 8         Atar  20.5169  -13.0499     76.14        21           0        8.75
# 9       Atuona  -9.8000 -139.0333     78.21        76           1       14.12
#
#   Country Current Description
# 0      PF       moderate rain
# 1      ZA     overcast clouds
# 2      PG     overcast clouds
# 3      DJ           clear sky
# 4      ZA     overcast clouds
# 5      RU     overcast clouds
# 6      ZA     overcast clouds
# 7      AU     overcast clouds
# 8      MR           clear sky
# 9      PF           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows: "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Rikitea      PF -23.1203 -134.9692     73.27        89         100
# 1  East London      ZA -33.0153   27.9116     64.98        79         100
# 2        Wewak      PG  -3.5534  143.6268     86.11        66         100
# 3       Jibuti      DJ  11.5000   42.5000     69.75        76           4
# 4  Port Alfred      ZA -33.5906   26.8910     62.19        95          98
# 5     Khatanga      RU  71.9667  102.5000    -27.71       100          94
# 6     Hermanus      ZA -34.4187   19.2345     52.81        72          97
# 7   Codrington      AU -38.2667  141.9667     58.21        65          89
# 8         Atar      MR  20.5169  -13.0499     76.14        21           0
# 9       Atuona      PF  -9.8000 -139.0333     78.21        76           1
#
#    Wind Speed Current Description
# 0       24.02       moderate rain
# 1        2.19     overcast clouds
# 2        4.63     overcast clouds
# 3       10.13           clear sky
# 4        6.31     overcast clouds
# 5        5.10     overcast clouds
# 6        4.59     overcast clouds
# 7        9.71     overcast clouds
# 8        8.75           clear sky
# 9       14.12           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
